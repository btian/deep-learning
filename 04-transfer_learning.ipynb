# %%
import torch
from torch import nn
from torch import optim
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import copy
from datetime import datetime

plt.ion()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
tx = transforms.Compose(
    [transforms.Resize((224, 224)), 
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

BATCH_SIZE = 32

train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=tx)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

validate_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=tx)
validate_loader = DataLoader(validate_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=8)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Use a pretrained ResNet model, reset the final layer to number of classes for our dataset.

# %%
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, len(classes))
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %% [markdown]
# Tune weights of the model.

# %%
# best_model = copy.deepcopy(model.state_dict())
epochs = 10
for epoch in range(epochs):
  running_loss = 0.0
  for i, data in enumerate(train_loader, 0):
    inputs, labels = data[0].to(device), data[1].to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    if i % 100 == 99:  # print every 100 mini-batches
      print(f'{datetime.now().time().replace(microsecond=0)} --- '
            f'Epoch: {epoch + 1}\t'
            f'Batch: {i + 1}\t'
            f'Loss: {running_loss / 100:.3f}')
      running_loss = 0.0
  correct = 0
  total = 0

  with torch.no_grad():
    for data in validate_loader:
      images, labels = data[0].to(device), data[1].to(device)
      outputs = model(images)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()
  print(f'{correct} correct predictions out of {total}. Accuracy: {100 * correct / total}')
# Out:
# 03:57:54 --- Epoch: 1	Batch: 100	Loss: 1.251
# 03:58:04 --- Epoch: 1	Batch: 200	Loss: 0.964
# 03:58:14 --- Epoch: 1	Batch: 300	Loss: 0.820
# 03:58:24 --- Epoch: 1	Batch: 400	Loss: 0.782
# 03:58:34 --- Epoch: 1	Batch: 500	Loss: 0.712
# 03:58:44 --- Epoch: 1	Batch: 600	Loss: 0.670
# 03:58:54 --- Epoch: 1	Batch: 700	Loss: 0.627
# 03:59:04 --- Epoch: 1	Batch: 800	Loss: 0.619
# 03:59:15 --- Epoch: 1	Batch: 900	Loss: 0.605
# 03:59:25 --- Epoch: 1	Batch: 1000	Loss: 0.569
# 03:59:35 --- Epoch: 1	Batch: 1100	Loss: 0.546
# 03:59:46 --- Epoch: 1	Batch: 1200	Loss: 0.517
# 03:59:56 --- Epoch: 1	Batch: 1300	Loss: 0.548
# 04:00:06 --- Epoch: 1	Batch: 1400	Loss: 0.522
# 04:00:17 --- Epoch: 1	Batch: 1500	Loss: 0.446
# 8278 correct predictions out of 10000. Accuracy: 82.78
# 04:00:51 --- Epoch: 2	Batch: 100	Loss: 0.402
# 04:01:02 --- Epoch: 2	Batch: 200	Loss: 0.405
# 04:01:12 --- Epoch: 2	Batch: 300	Loss: 0.412
# 04:01:23 --- Epoch: 2	Batch: 400	Loss: 0.412
# 04:01:33 --- Epoch: 2	Batch: 500	Loss: 0.428
# 04:01:44 --- Epoch: 2	Batch: 600	Loss: 0.401
# 04:01:54 --- Epoch: 2	Batch: 700	Loss: 0.428
# 04:02:05 --- Epoch: 2	Batch: 800	Loss: 0.391
# 04:02:15 --- Epoch: 2	Batch: 900	Loss: 0.374
# 04:02:26 --- Epoch: 2	Batch: 1000	Loss: 0.388
# 04:02:36 --- Epoch: 2	Batch: 1100	Loss: 0.406
# 04:02:47 --- Epoch: 2	Batch: 1200	Loss: 0.364
# 04:02:57 --- Epoch: 2	Batch: 1300	Loss: 0.376
# 04:03:08 --- Epoch: 2	Batch: 1400	Loss: 0.384
# 04:03:19 --- Epoch: 2	Batch: 1500	Loss: 0.403
# 8742 correct predictions out of 10000. Accuracy: 87.42
# 04:03:54 --- Epoch: 3	Batch: 100	Loss: 0.254
# 04:04:04 --- Epoch: 3	Batch: 200	Loss: 0.246
# 04:04:15 --- Epoch: 3	Batch: 300	Loss: 0.314
# 04:04:25 --- Epoch: 3	Batch: 400	Loss: 0.282
# 04:04:36 --- Epoch: 3	Batch: 500	Loss: 0.287
# 04:04:46 --- Epoch: 3	Batch: 600	Loss: 0.297
# 04:04:57 --- Epoch: 3	Batch: 700	Loss: 0.296
# 04:05:07 --- Epoch: 3	Batch: 800	Loss: 0.306
# 04:05:18 --- Epoch: 3	Batch: 900	Loss: 0.324
# 04:05:29 --- Epoch: 3	Batch: 1000	Loss: 0.290
# 04:05:39 --- Epoch: 3	Batch: 1100	Loss: 0.286
# 04:05:50 --- Epoch: 3	Batch: 1200	Loss: 0.313
# 04:06:00 --- Epoch: 3	Batch: 1300	Loss: 0.304
# 04:06:11 --- Epoch: 3	Batch: 1400	Loss: 0.321
# 04:06:22 --- Epoch: 3	Batch: 1500	Loss: 0.294
# 8683 correct predictions out of 10000. Accuracy: 86.83
# 04:06:57 --- Epoch: 4	Batch: 100	Loss: 0.180
# 04:07:07 --- Epoch: 4	Batch: 200	Loss: 0.188
# 04:07:18 --- Epoch: 4	Batch: 300	Loss: 0.195
# 04:07:28 --- Epoch: 4	Batch: 400	Loss: 0.195
# 04:07:39 --- Epoch: 4	Batch: 500	Loss: 0.224
# 04:07:49 --- Epoch: 4	Batch: 600	Loss: 0.225
# 04:08:00 --- Epoch: 4	Batch: 700	Loss: 0.197
# 04:08:11 --- Epoch: 4	Batch: 800	Loss: 0.214
# 04:08:21 --- Epoch: 4	Batch: 900	Loss: 0.203
# 04:08:32 --- Epoch: 4	Batch: 1000	Loss: 0.227
# 04:08:42 --- Epoch: 4	Batch: 1100	Loss: 0.227
# 04:08:53 --- Epoch: 4	Batch: 1200	Loss: 0.237
# 04:09:04 --- Epoch: 4	Batch: 1300	Loss: 0.226
# 04:09:14 --- Epoch: 4	Batch: 1400	Loss: 0.231
# 04:09:25 --- Epoch: 4	Batch: 1500	Loss: 0.227
# 8881 correct predictions out of 10000. Accuracy: 88.81
# 04:10:00 --- Epoch: 5	Batch: 100	Loss: 0.112
# 04:10:10 --- Epoch: 5	Batch: 200	Loss: 0.106
# 04:10:21 --- Epoch: 5	Batch: 300	Loss: 0.131
# 04:10:31 --- Epoch: 5	Batch: 400	Loss: 0.140
# 04:10:42 --- Epoch: 5	Batch: 500	Loss: 0.197
# 04:10:52 --- Epoch: 5	Batch: 600	Loss: 0.185
# 04:11:03 --- Epoch: 5	Batch: 700	Loss: 0.161
# 04:11:14 --- Epoch: 5	Batch: 800	Loss: 0.158
# 04:11:24 --- Epoch: 5	Batch: 900	Loss: 0.154
# 04:11:35 --- Epoch: 5	Batch: 1000	Loss: 0.168
# 04:11:45 --- Epoch: 5	Batch: 1100	Loss: 0.153
# 04:11:56 --- Epoch: 5	Batch: 1200	Loss: 0.166
# 04:12:07 --- Epoch: 5	Batch: 1300	Loss: 0.177
# 04:12:17 --- Epoch: 5	Batch: 1400	Loss: 0.163
# 04:12:28 --- Epoch: 5	Batch: 1500	Loss: 0.176
# 8900 correct predictions out of 10000. Accuracy: 89.0
# 04:13:02 --- Epoch: 6	Batch: 100	Loss: 0.102
# 04:13:13 --- Epoch: 6	Batch: 200	Loss: 0.080
# 04:13:23 --- Epoch: 6	Batch: 300	Loss: 0.101
# 04:13:34 --- Epoch: 6	Batch: 400	Loss: 0.096
# 04:13:45 --- Epoch: 6	Batch: 500	Loss: 0.099
# 04:13:55 --- Epoch: 6	Batch: 600	Loss: 0.138
# 04:14:06 --- Epoch: 6	Batch: 700	Loss: 0.137
# 04:14:16 --- Epoch: 6	Batch: 800	Loss: 0.100
# 04:14:27 --- Epoch: 6	Batch: 900	Loss: 0.125
# 04:14:37 --- Epoch: 6	Batch: 1000	Loss: 0.137
# 04:14:48 --- Epoch: 6	Batch: 1100	Loss: 0.143
# 04:14:59 --- Epoch: 6	Batch: 1200	Loss: 0.143
# 04:15:09 --- Epoch: 6	Batch: 1300	Loss: 0.143
# 04:15:20 --- Epoch: 6	Batch: 1400	Loss: 0.137
# 04:15:30 --- Epoch: 6	Batch: 1500	Loss: 0.126
# 8946 correct predictions out of 10000. Accuracy: 89.46
# 04:16:05 --- Epoch: 7	Batch: 100	Loss: 0.063
# 04:16:16 --- Epoch: 7	Batch: 200	Loss: 0.067
# 04:16:26 --- Epoch: 7	Batch: 300	Loss: 0.061
# 04:16:37 --- Epoch: 7	Batch: 400	Loss: 0.072
# 04:16:47 --- Epoch: 7	Batch: 500	Loss: 0.090
# 04:16:58 --- Epoch: 7	Batch: 600	Loss: 0.093
# 04:17:08 --- Epoch: 7	Batch: 700	Loss: 0.114
# 04:17:19 --- Epoch: 7	Batch: 800	Loss: 0.084
# 04:17:30 --- Epoch: 7	Batch: 900	Loss: 0.081
# 04:17:40 --- Epoch: 7	Batch: 1000	Loss: 0.118
# 04:17:51 --- Epoch: 7	Batch: 1100	Loss: 0.130
# 04:18:01 --- Epoch: 7	Batch: 1200	Loss: 0.129
# 04:18:12 --- Epoch: 7	Batch: 1300	Loss: 0.118
# 04:18:22 --- Epoch: 7	Batch: 1400	Loss: 0.123
# 04:18:33 --- Epoch: 7	Batch: 1500	Loss: 0.118
# 8955 correct predictions out of 10000. Accuracy: 89.55
# 04:19:08 --- Epoch: 8	Batch: 100	Loss: 0.050
# 04:19:18 --- Epoch: 8	Batch: 200	Loss: 0.060
# 04:19:29 --- Epoch: 8	Batch: 300	Loss: 0.056
# 04:19:39 --- Epoch: 8	Batch: 400	Loss: 0.054
# 04:19:50 --- Epoch: 8	Batch: 500	Loss: 0.068
# 04:20:01 --- Epoch: 8	Batch: 600	Loss: 0.054
# 04:20:11 --- Epoch: 8	Batch: 700	Loss: 0.078
# 04:20:22 --- Epoch: 8	Batch: 800	Loss: 0.078
# 04:20:32 --- Epoch: 8	Batch: 900	Loss: 0.095
# 04:20:43 --- Epoch: 8	Batch: 1000	Loss: 0.102
# 04:20:53 --- Epoch: 8	Batch: 1100	Loss: 0.089
# 04:21:04 --- Epoch: 8	Batch: 1200	Loss: 0.105
# 04:21:15 --- Epoch: 8	Batch: 1300	Loss: 0.099
# 04:21:25 --- Epoch: 8	Batch: 1400	Loss: 0.116
# 04:21:36 --- Epoch: 8	Batch: 1500	Loss: 0.094
# 8975 correct predictions out of 10000. Accuracy: 89.75
# 04:22:10 --- Epoch: 9	Batch: 100	Loss: 0.049
# 04:22:21 --- Epoch: 9	Batch: 200	Loss: 0.058
# 04:22:32 --- Epoch: 9	Batch: 300	Loss: 0.064
# 04:22:42 --- Epoch: 9	Batch: 400	Loss: 0.053
# 04:22:53 --- Epoch: 9	Batch: 500	Loss: 0.083
# 04:23:03 --- Epoch: 9	Batch: 600	Loss: 0.078
# 04:23:14 --- Epoch: 9	Batch: 700	Loss: 0.073
# 04:23:25 --- Epoch: 9	Batch: 800	Loss: 0.066
# 04:23:35 --- Epoch: 9	Batch: 900	Loss: 0.082
# 04:23:46 --- Epoch: 9	Batch: 1000	Loss: 0.095
# 04:23:56 --- Epoch: 9	Batch: 1100	Loss: 0.102
# 04:24:07 --- Epoch: 9	Batch: 1200	Loss: 0.089
# 04:24:18 --- Epoch: 9	Batch: 1300	Loss: 0.078
# 04:24:28 --- Epoch: 9	Batch: 1400	Loss: 0.051
# 04:24:39 --- Epoch: 9	Batch: 1500	Loss: 0.051
# 8915 correct predictions out of 10000. Accuracy: 89.15
# 04:25:14 --- Epoch: 10	Batch: 100	Loss: 0.054
# 04:25:24 --- Epoch: 10	Batch: 200	Loss: 0.040
# 04:25:35 --- Epoch: 10	Batch: 300	Loss: 0.047
# 04:25:45 --- Epoch: 10	Batch: 400	Loss: 0.058
# 04:25:56 --- Epoch: 10	Batch: 500	Loss: 0.053
# 04:26:06 --- Epoch: 10	Batch: 600	Loss: 0.059
# 04:26:17 --- Epoch: 10	Batch: 700	Loss: 0.066
# 04:26:28 --- Epoch: 10	Batch: 800	Loss: 0.047
# 04:26:38 --- Epoch: 10	Batch: 900	Loss: 0.061
# 04:26:49 --- Epoch: 10	Batch: 1000	Loss: 0.073
# 04:26:59 --- Epoch: 10	Batch: 1100	Loss: 0.065
# 04:27:10 --- Epoch: 10	Batch: 1200	Loss: 0.071
# 04:27:21 --- Epoch: 10	Batch: 1300	Loss: 0.049
# 04:27:31 --- Epoch: 10	Batch: 1400	Loss: 0.073
# 04:27:42 --- Epoch: 10	Batch: 1500	Loss: 0.089
# 8925 correct predictions out of 10000. Accuracy: 89.25
